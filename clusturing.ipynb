# %%
import sys
import os
import yaml
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

sys.path.insert(0, '../')
#import utils.utils as utils
from pathlib import Path
from sklearn.model_selection import train_test_split


# TensorFlow imports
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras import layers

from data_utils import DataGen, get_gen
from model import GMM_Survival
from losses import Losses
from eval_utils_1 import cindex_metric
from networks import (VGGEncoder, VGGDecoder, Encoder, Decoder, Encoder_small, Decoder_small)
from utils import weibull_scale, weibull_log_pdf, tensor_slice

# Survival Clustering
from sklearn.cluster import KMeans
from lifelines import CoxPHFitter
from lifelines import KaplanMeierFitter

# %matplotlib inline

# %% [markdown]
# ### VADESC

# %%
# Pretrain autoencoder
checkpoint_path = "autoencoder/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

tfd = tfp.distributions
tfkl = tf.keras.layers
tfpl = tfp.layers
tfk = tf.keras

# %% [markdown]
# {'data': {'data_name': 'test'}, 'training': {'eval_frequency': 200, 'inp_shape': 11684, 'latent_dim': 2, 'num_clusters': 2, 'activation': 'none', 'monte_carlo': 1, 'learn_prior': True, 'weibull_shape': 1, 'survival': True, 'sample_surv': False}}

# %%
#plotting kmf each clusters
def plot_bigroup_kaplan_meier(t, d,c_, dir=None, postfix=None, legend=False, legend_outside=False):
    labels = np.unique(c_)
    for l in labels:
        kmf = KaplanMeierFitter()
        kmf.fit(t[c_ == l], d[c_ == l], label="cluster " + str(int(l + 1)))
        kmf.plot(ci_show=True, alpha=0.75, color=CB_COLOR_CYCLE[int(l)], linewidth=2)

    plt.xlabel("Time")
    plt.ylabel("Survival Probability")

# %%
def setup_seed(seed):
    random.seed(seed)  
    np.random.seed(seed) 
    tf.random.set_seed(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

# %%
# Fix random seed
seed = 20220229
setup_seed(seed)

# %%
# Load config file for the MNIST
project_dir = os.path.dirname(os.getcwd())
config_path = Path(os.path.join(project_dir, 'configs/test.yml'))
with config_path.open(mode='r') as yamlfile:
    configs = yaml.safe_load(yamlfile)
print(configs)
# Out:
# {'data': {'data_name': 'test'}, 'training': {'eval_frequency': 200, 'inp_shape': 11684, 'latent_dim': 2, 'num_clusters': 2, 'activation': 'none', 'monte_carlo': 1, 'learn_prior': True, 'weibull_shape': 1, 'survival': True, 'sample_surv': False}}

# %%
configs
# Out:
# {'data': {'data_name': 'test'},
#  'training': {'eval_frequency': 200,
#   'inp_shape': 11684,
#   'latent_dim': 2,
#   'num_clusters': 2,
#   'activation': 'none',
#   'monte_carlo': 1,
#   'learn_prior': True,
#   'weibull_shape': 1,
#   'survival': True,
#   'sample_surv': False}}

# %%
# Define reconstruction loss function
losses = Losses(configs)
rec_loss = losses.loss_reconstruction_mse

# %%
#load TCGA data
GeneCount = np.load('./processedData/GeneCount.npy',allow_pickle=True)
TTE = np.load('./processedData/TTE.npy',allow_pickle=True)
EVENT = np.load('./processedData/Event.npy',allow_pickle=True)

X_train = GeneCount
Y_train = np.stack([TTE,EVENT],axis=1)

X_train,X_test,Y_train,Y_test=train_test_split(X_train,Y_train,test_size=0.2,shuffle=True,random_state=44)

# %%
X_train.shape
# Out:
# (2353, 11684)

# %%
# Fix seeds
setup_seed(seed)

# %%
# Construct the model & optimizer
model = GMM_Survival(**configs['training'])
optimizer = tf.keras.optimizers.Adam(learning_rate=0.00001)
model.compile(optimizer, loss={"output_1": rec_loss},
              metrics={"output_2": cindex_metric})

# Use survival times during training
tf.keras.backend.set_value(model.use_t, np.array([1.0]))

# %%
# Data generators
gen_train = get_gen(X_train, Y_train,configs, 16)
gen_test = get_gen(X_test, Y_test, configs, 16, validation=True)

# %% [markdown]
# ### Training & Evaluation

# %%
# Fit the model
model.fit(gen_train,validation_data=gen_test, epochs=140, verbose=1)
model.summary()
# Out:
# Epoch 1/140
# WARNING:tensorflow:From C:\Users\user\anaconda3\envs\ai\lib\site-packages\tensorflow_probability\python\distributions\distribution.py:334: calling MultivariateNormalDiag.__init__ (from tensorflow_probability.python.distributions.mvn_diag) with scale_identity_multiplier is deprecated and will be removed after 2020-01-01.
# Instructions for updating:
# `scale_identity_multiplier` is deprecated; please combine it with `scale_diag` directly instead.
# WARNING:tensorflow:From C:\Users\user\anaconda3\envs\ai\lib\site-packages\tensorflow_probability\python\distributions\distribution.py:334: calling TransformedDistribution.__init__ (from tensorflow_probability.python.distributions.transformed_distribution) with batch_shape is deprecated and will be removed after 2020-06-01.
# Instructions for updating:
# `batch_shape` and `event_shape` args are deprecated. Please use `tfd.Sample`, `tfd.Independent`, and broadcasted parameters of the base distribution instead. For example, replace `tfd.TransformedDistribution(tfd.Normal(0., 1.), tfb.Exp(), batch_shape=[2, 3], event_shape=[4])` with `tfd.TransformedDistrbution(tfd.Sample(tfd.Normal(tf.zeros([2, 3]), 1.),sample_shape=[4]), tfb.Exp())` or `tfd.TransformedDistribution(tfd.Independent(tfd.Normal(tf.zeros([2, 3, 4]), 1.), reinterpreted_batch_ndims=1), tfb.Exp())`.
# WARNING:tensorflow:From C:\Users\user\anaconda3\envs\ai\lib\site-packages\tensorflow_probability\python\distributions\distribution.py:334: calling TransformedDistribution.__init__ (from tensorflow_probability.python.distributions.transformed_distribution) with event_shape is deprecated and will be removed after 2020-06-01.
# Instructions for updating:
# `batch_shape` and `event_shape` args are deprecated. Please use `tfd.Sample`, `tfd.Independent`, and broadcasted parameters of the base distribution instead. For example, replace `tfd.TransformedDistribution(tfd.Normal(0., 1.), tfb.Exp(), batch_shape=[2, 3], event_shape=[4])` with `tfd.TransformedDistrbution(tfd.Sample(tfd.Normal(tf.zeros([2, 3]), 1.),sample_shape=[4]), tfb.Exp())` or `tfd.TransformedDistribution(tfd.Independent(tfd.Normal(tf.zeros([2, 3, 4]), 1.), reinterpreted_batch_ndims=1), tfb.Exp())`.
# 147/147 [==============================] - 7s 23ms/step - loss: 1741.0654 - output_1_loss: 1698.9917 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 45.5951 - loss_prior: 0.6931 - loss_variational_1: -5.7164 - loss_variational_2: -0.2265 - loss_survival: 1.7281 - val_loss: 1052.9126 - val_output_1_loss: 1041.2976 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 16.3080 - val_loss_prior: 0.6925 - val_loss_variational_1: -6.5830 - val_loss_variational_2: -0.0024 - val_loss_survival: 1.2000
# Epoch 2/140
# 147/147 [==============================] - 3s 22ms/step - loss: 245.5540 - output_1_loss: 214.1754 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 32.6253 - loss_prior: 0.6916 - loss_variational_1: -2.9704 - loss_variational_2: -0.0335 - loss_survival: 1.0655 - val_loss: 78.6596 - val_output_1_loss: 54.6623 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 23.0811 - val_loss_prior: 0.6905 - val_loss_variational_1: -0.8256 - val_loss_variational_2: -4.0107e-07 - val_loss_survival: 1.0514
# Epoch 3/140
# 147/147 [==============================] - 3s 22ms/step - loss: 75.9260 - output_1_loss: 53.7046 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 20.8161 - loss_prior: 0.6896 - loss_variational_1: -0.3873 - loss_variational_2: -2.1785e-05 - loss_survival: 1.1031 - val_loss: 72.0033 - val_output_1_loss: 52.3750 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 17.8792 - val_loss_prior: 0.6887 - val_loss_variational_1: -0.0704 - val_loss_variational_2: -2.3012e-06 - val_loss_survival: 1.1308
# Epoch 4/140
# 147/147 [==============================] - 3s 22ms/step - loss: 71.1439 - output_1_loss: 52.7894 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 16.3800 - loss_prior: 0.6879 - loss_variational_1: 0.0930 - loss_variational_2: -2.5071e-05 - loss_survival: 1.1936 - val_loss: 69.1290 - val_output_1_loss: 52.4349 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 14.5537 - val_loss_prior: 0.6870 - val_loss_variational_1: 0.2290 - val_loss_variational_2: -1.3162e-05 - val_loss_survival: 1.2244
# Epoch 5/140
# 147/147 [==============================] - 3s 21ms/step - loss: 68.6334 - output_1_loss: 52.6953 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 13.6757 - loss_prior: 0.6862 - loss_variational_1: 0.2871 - loss_variational_2: -1.2359e-04 - loss_survival: 1.2892 - val_loss: 67.2297 - val_output_1_loss: 52.3689 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 12.4846 - val_loss_prior: 0.6855 - val_loss_variational_1: 0.3788 - val_loss_variational_2: -6.2800e-05 - val_loss_survival: 1.3120
# Epoch 6/140
# 147/147 [==============================] - 3s 21ms/step - loss: 67.0767 - output_1_loss: 52.6984 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 11.9034 - loss_prior: 0.6847 - loss_variational_1: 0.4188 - loss_variational_2: -2.5995e-04 - loss_survival: 1.3716 - val_loss: 66.2357 - val_output_1_loss: 52.6964 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 11.0083 - val_loss_prior: 0.6839 - val_loss_variational_1: 0.4489 - val_loss_variational_2: -2.6104e-04 - val_loss_survival: 1.3984
# Epoch 7/140
# 147/147 [==============================] - 3s 21ms/step - loss: 65.9284 - output_1_loss: 52.6811 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 10.6399 - loss_prior: 0.6832 - loss_variational_1: 0.4827 - loss_variational_2: -8.2491e-04 - loss_survival: 1.4424 - val_loss: 64.9604 - val_output_1_loss: 52.4635 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 9.8309 - val_loss_prior: 0.6824 - val_loss_variational_1: 0.5146 - val_loss_variational_2: -0.0010 - val_loss_survival: 1.4700
# Epoch 8/140
# 147/147 [==============================] - 3s 20ms/step - loss: 65.0531 - output_1_loss: 52.6489 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 9.6820 - loss_prior: 0.6816 - loss_variational_1: 0.5360 - loss_variational_2: -0.0021 - loss_survival: 1.5066 - val_loss: 63.9641 - val_output_1_loss: 52.1484 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 9.0481 - val_loss_prior: 0.6809 - val_loss_variational_1: 0.5673 - val_loss_variational_2: -0.0028 - val_loss_survival: 1.5222
# Epoch 9/140
# 147/147 [==============================] - 3s 21ms/step - loss: 64.4041 - output_1_loss: 52.6501 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 8.9322 - loss_prior: 0.6802 - loss_variational_1: 0.5788 - loss_variational_2: -0.0054 - loss_survival: 1.5684 - val_loss: 63.3777 - val_output_1_loss: 52.1546 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 8.3649 - val_loss_prior: 0.6794 - val_loss_variational_1: 0.5999 - val_loss_variational_2: -0.0072 - val_loss_survival: 1.5860
# Epoch 10/140
# 147/147 [==============================] - 3s 21ms/step - loss: 63.8604 - output_1_loss: 52.6389 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 8.3201 - loss_prior: 0.6787 - loss_variational_1: 0.6096 - loss_variational_2: -0.0125 - loss_survival: 1.6256 - val_loss: 63.0338 - val_output_1_loss: 52.2523 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 7.8383 - val_loss_prior: 0.6780 - val_loss_variational_1: 0.6344 - val_loss_variational_2: -0.0143 - val_loss_survival: 1.6451
# Epoch 11/140
# 147/147 [==============================] - 3s 21ms/step - loss: 63.5038 - output_1_loss: 52.6562 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 7.8351 - loss_prior: 0.6773 - loss_variational_1: 0.6758 - loss_variational_2: -0.0237 - loss_survival: 1.6831 - val_loss: 62.6912 - val_output_1_loss: 52.2214 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 7.4043 - val_loss_prior: 0.6766 - val_loss_variational_1: 0.7081 - val_loss_variational_2: -0.0269 - val_loss_survival: 1.7077
# Epoch 12/140
# 147/147 [==============================] - 3s 21ms/step - loss: 63.1628 - output_1_loss: 52.6201 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 7.4433 - loss_prior: 0.6760 - loss_variational_1: 0.7271 - loss_variational_2: -0.0409 - loss_survival: 1.7372 - val_loss: 62.5052 - val_output_1_loss: 52.3379 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 7.0571 - val_loss_prior: 0.6753 - val_loss_variational_1: 0.7315 - val_loss_variational_2: -0.0455 - val_loss_survival: 1.7490
# Epoch 13/140
# 147/147 [==============================] - 3s 21ms/step - loss: 62.9472 - output_1_loss: 52.6273 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 7.1366 - loss_prior: 0.6748 - loss_variational_1: 0.7938 - loss_variational_2: -0.0653 - loss_survival: 1.7799 - val_loss: 62.1550 - val_output_1_loss: 52.1763 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 6.7500 - val_loss_prior: 0.6742 - val_loss_variational_1: 0.8312 - val_loss_variational_2: -0.0731 - val_loss_survival: 1.7963
# Epoch 14/140
# 147/147 [==============================] - 3s 20ms/step - loss: 62.8661 - output_1_loss: 52.7053 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 6.8911 - loss_prior: 0.6738 - loss_variational_1: 0.8701 - loss_variational_2: -0.0958 - loss_survival: 1.8216 - val_loss: 62.4813 - val_output_1_loss: 52.7049 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 6.4719 - val_loss_prior: 0.6733 - val_loss_variational_1: 0.8930 - val_loss_variational_2: -0.1103 - val_loss_survival: 1.8485
# Epoch 15/140
# 147/147 [==============================] - 3s 21ms/step - loss: 62.5648 - output_1_loss: 52.6347 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 6.6765 - loss_prior: 0.6729 - loss_variational_1: 0.8467 - loss_variational_2: -0.1307 - loss_survival: 1.8647 - val_loss: 61.9986 - val_output_1_loss: 52.4391 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 6.3374 - val_loss_prior: 0.6723 - val_loss_variational_1: 0.8098 - val_loss_variational_2: -0.1381 - val_loss_survival: 1.8780
# Epoch 16/140
# 147/147 [==============================] - 3s 21ms/step - loss: 62.4167 - output_1_loss: 52.6213 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 6.5145 - loss_prior: 0.6723 - loss_variational_1: 0.8838 - loss_variational_2: -0.1703 - loss_survival: 1.8950 - val_loss: 62.2867 - val_output_1_loss: 52.8720 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 6.1224 - val_loss_prior: 0.6720 - val_loss_variational_1: 0.8899 - val_loss_variational_2: -0.1939 - val_loss_survival: 1.9244
# Epoch 17/140
# 147/147 [==============================] - 3s 20ms/step - loss: 62.3127 - output_1_loss: 52.6293 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 6.3670 - loss_prior: 0.6719 - loss_variational_1: 0.9331 - loss_variational_2: -0.2150 - loss_survival: 1.9264 - val_loss: 61.6577 - val_output_1_loss: 52.2945 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 6.0413 - val_loss_prior: 0.6713 - val_loss_variational_1: 0.9271 - val_loss_variational_2: -0.2204 - val_loss_survival: 1.9439
# Epoch 18/140
# 147/147 [==============================] - 3s 21ms/step - loss: 62.1966 - output_1_loss: 52.6345 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 6.2518 - loss_prior: 0.6717 - loss_variational_1: 0.9493 - loss_variational_2: -0.2595 - loss_survival: 1.9489 - val_loss: 61.6718 - val_output_1_loss: 52.4088 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.9289 - val_loss_prior: 0.6714 - val_loss_variational_1: 0.9835 - val_loss_variational_2: -0.2778 - val_loss_survival: 1.9570
# Epoch 19/140
# 147/147 [==============================] - 3s 21ms/step - loss: 62.0931 - output_1_loss: 52.6115 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 6.1555 - loss_prior: 0.6719 - loss_variational_1: 0.9976 - loss_variational_2: -0.3054 - loss_survival: 1.9620 - val_loss: 61.6930 - val_output_1_loss: 52.4808 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.8340 - val_loss_prior: 0.6719 - val_loss_variational_1: 1.0621 - val_loss_variational_2: -0.3387 - val_loss_survival: 1.9829
# Epoch 20/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.9941 - output_1_loss: 52.6157 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 6.0584 - loss_prior: 0.6722 - loss_variational_1: 1.0132 - loss_variational_2: -0.3499 - loss_survival: 1.9846 - val_loss: 61.4425 - val_output_1_loss: 52.3523 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.8130 - val_loss_prior: 0.6713 - val_loss_variational_1: 0.9771 - val_loss_variational_2: -0.3487 - val_loss_survival: 1.9775
# Epoch 21/140
# 147/147 [==============================] - 3s 21ms/step - loss: 62.0110 - output_1_loss: 52.7102 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.9984 - loss_prior: 0.6729 - loss_variational_1: 1.0282 - loss_variational_2: -0.3945 - loss_survival: 1.9958 - val_loss: 61.1977 - val_output_1_loss: 52.2034 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.7189 - val_loss_prior: 0.6723 - val_loss_variational_1: 1.0127 - val_loss_variational_2: -0.4055 - val_loss_survival: 1.9958
# Epoch 22/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.8958 - output_1_loss: 52.6750 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.9193 - loss_prior: 0.6738 - loss_variational_1: 1.0626 - loss_variational_2: -0.4348 - loss_survival: 1.9998 - val_loss: 61.2845 - val_output_1_loss: 52.3284 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.6454 - val_loss_prior: 0.6738 - val_loss_variational_1: 1.0865 - val_loss_variational_2: -0.4619 - val_loss_survival: 2.0123
# Epoch 23/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.8153 - output_1_loss: 52.6526 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.8604 - loss_prior: 0.6751 - loss_variational_1: 1.0966 - loss_variational_2: -0.4758 - loss_survival: 2.0066 - val_loss: 61.2008 - val_output_1_loss: 52.3060 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.5997 - val_loss_prior: 0.6750 - val_loss_variational_1: 1.1100 - val_loss_variational_2: -0.5000 - val_loss_survival: 2.0102
# Epoch 24/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.6665 - output_1_loss: 52.5925 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.7967 - loss_prior: 0.6765 - loss_variational_1: 1.0957 - loss_variational_2: -0.5124 - loss_survival: 2.0175 - val_loss: 61.8789 - val_output_1_loss: 53.0444 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.5514 - val_loss_prior: 0.6754 - val_loss_variational_1: 1.1077 - val_loss_variational_2: -0.5178 - val_loss_survival: 2.0179
# Epoch 25/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.6669 - output_1_loss: 52.6630 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.7447 - loss_prior: 0.6782 - loss_variational_1: 1.1086 - loss_variational_2: -0.5445 - loss_survival: 2.0169 - val_loss: 61.2642 - val_output_1_loss: 52.6089 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.4695 - val_loss_prior: 0.6787 - val_loss_variational_1: 1.0677 - val_loss_variational_2: -0.5775 - val_loss_survival: 2.0170
# Epoch 26/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.7055 - output_1_loss: 52.7792 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.6927 - loss_prior: 0.6798 - loss_variational_1: 1.0951 - loss_variational_2: -0.5669 - loss_survival: 2.0257 - val_loss: 61.0256 - val_output_1_loss: 52.2547 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.4492 - val_loss_prior: 0.6808 - val_loss_variational_1: 1.2604 - val_loss_variational_2: -0.6076 - val_loss_survival: 1.9882
# Epoch 27/140
# 147/147 [==============================] - 3s 22ms/step - loss: 61.5980 - output_1_loss: 52.6846 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.6249 - loss_prior: 0.6814 - loss_variational_1: 1.1862 - loss_variational_2: -0.5905 - loss_survival: 2.0114 - val_loss: 60.8026 - val_output_1_loss: 52.2303 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.3450 - val_loss_prior: 0.6815 - val_loss_variational_1: 1.1241 - val_loss_variational_2: -0.6171 - val_loss_survival: 2.0388
# Epoch 28/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.4319 - output_1_loss: 52.6035 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.5727 - loss_prior: 0.6829 - loss_variational_1: 1.1553 - loss_variational_2: -0.6043 - loss_survival: 2.0218 - val_loss: 60.8148 - val_output_1_loss: 52.2943 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.3322 - val_loss_prior: 0.6841 - val_loss_variational_1: 1.1448 - val_loss_variational_2: -0.6421 - val_loss_survival: 2.0014
# Epoch 29/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.4568 - output_1_loss: 52.6615 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.5210 - loss_prior: 0.6850 - loss_variational_1: 1.1935 - loss_variational_2: -0.6211 - loss_survival: 2.0170 - val_loss: 61.0054 - val_output_1_loss: 52.4894 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.2899 - val_loss_prior: 0.6847 - val_loss_variational_1: 1.1738 - val_loss_variational_2: -0.6470 - val_loss_survival: 2.0146
# Epoch 30/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.3344 - output_1_loss: 52.5767 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.4630 - loss_prior: 0.6866 - loss_variational_1: 1.2104 - loss_variational_2: -0.6302 - loss_survival: 2.0279 - val_loss: 60.9608 - val_output_1_loss: 52.5256 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.2513 - val_loss_prior: 0.6871 - val_loss_variational_1: 1.1683 - val_loss_variational_2: -0.6619 - val_loss_survival: 1.9903
# Epoch 31/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.2939 - output_1_loss: 52.6072 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.4075 - loss_prior: 0.6886 - loss_variational_1: 1.2144 - loss_variational_2: -0.6387 - loss_survival: 2.0149 - val_loss: 60.8829 - val_output_1_loss: 52.4894 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.1330 - val_loss_prior: 0.6896 - val_loss_variational_1: 1.2223 - val_loss_variational_2: -0.6721 - val_loss_survival: 2.0208
# Epoch 32/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.2522 - output_1_loss: 52.6008 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.3626 - loss_prior: 0.6903 - loss_variational_1: 1.2281 - loss_variational_2: -0.6426 - loss_survival: 2.0131 - val_loss: 60.7776 - val_output_1_loss: 52.4841 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.1312 - val_loss_prior: 0.6913 - val_loss_variational_1: 1.1714 - val_loss_variational_2: -0.6768 - val_loss_survival: 1.9764
# Epoch 33/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.2421 - output_1_loss: 52.6379 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.2926 - loss_prior: 0.6916 - loss_variational_1: 1.2482 - loss_variational_2: -0.6471 - loss_survival: 2.0189 - val_loss: 60.8463 - val_output_1_loss: 52.5206 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.0742 - val_loss_prior: 0.6925 - val_loss_variational_1: 1.2425 - val_loss_variational_2: -0.6785 - val_loss_survival: 1.9949
# Epoch 34/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.2448 - output_1_loss: 52.6912 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.2534 - loss_prior: 0.6935 - loss_variational_1: 1.2480 - loss_variational_2: -0.6481 - loss_survival: 2.0068 - val_loss: 60.5645 - val_output_1_loss: 52.3318 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 5.0233 - val_loss_prior: 0.6949 - val_loss_variational_1: 1.2118 - val_loss_variational_2: -0.6790 - val_loss_survival: 1.9817
# Epoch 35/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.1659 - output_1_loss: 52.6692 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.2217 - loss_prior: 0.6949 - loss_variational_1: 1.2233 - loss_variational_2: -0.6466 - loss_survival: 2.0033 - val_loss: 60.7358 - val_output_1_loss: 52.5801 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.9210 - val_loss_prior: 0.6956 - val_loss_variational_1: 1.2005 - val_loss_variational_2: -0.6787 - val_loss_survival: 2.0173
# Epoch 36/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.4613 - output_1_loss: 52.9657 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.1966 - loss_prior: 0.6962 - loss_variational_1: 1.2596 - loss_variational_2: -0.6457 - loss_survival: 1.9889 - val_loss: 60.3558 - val_output_1_loss: 52.1511 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.9359 - val_loss_prior: 0.6968 - val_loss_variational_1: 1.2722 - val_loss_variational_2: -0.6766 - val_loss_survival: 1.9764
# Epoch 37/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.0841 - output_1_loss: 52.6149 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.1584 - loss_prior: 0.6966 - loss_variational_1: 1.2786 - loss_variational_2: -0.6443 - loss_survival: 1.9799 - val_loss: 60.5723 - val_output_1_loss: 52.4079 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.9219 - val_loss_prior: 0.6975 - val_loss_variational_1: 1.2505 - val_loss_variational_2: -0.6751 - val_loss_survival: 1.9696
# Epoch 38/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.1205 - output_1_loss: 52.6877 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.1126 - loss_prior: 0.6977 - loss_variational_1: 1.2914 - loss_variational_2: -0.6433 - loss_survival: 1.9745 - val_loss: 60.5205 - val_output_1_loss: 52.4197 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.8773 - val_loss_prior: 0.6983 - val_loss_variational_1: 1.2221 - val_loss_variational_2: -0.6723 - val_loss_survival: 1.9754
# Epoch 39/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.0791 - output_1_loss: 52.6596 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.0833 - loss_prior: 0.6984 - loss_variational_1: 1.2839 - loss_variational_2: -0.6395 - loss_survival: 1.9934 - val_loss: 61.4673 - val_output_1_loss: 53.4363 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.7753 - val_loss_prior: 0.7001 - val_loss_variational_1: 1.2202 - val_loss_variational_2: -0.6644 - val_loss_survival: 1.9997
# Epoch 40/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.0375 - output_1_loss: 52.6908 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.0600 - loss_prior: 0.6992 - loss_variational_1: 1.2460 - loss_variational_2: -0.6344 - loss_survival: 1.9759 - val_loss: 60.7897 - val_output_1_loss: 52.7437 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.7501 - val_loss_prior: 0.6998 - val_loss_variational_1: 1.2471 - val_loss_variational_2: -0.6651 - val_loss_survival: 2.0141
# Epoch 41/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.0459 - output_1_loss: 52.6785 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.0193 - loss_prior: 0.6994 - loss_variational_1: 1.2901 - loss_variational_2: -0.6335 - loss_survival: 1.9922 - val_loss: 60.4910 - val_output_1_loss: 52.5223 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.7563 - val_loss_prior: 0.7002 - val_loss_variational_1: 1.2020 - val_loss_variational_2: -0.6617 - val_loss_survival: 1.9719
# Epoch 42/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.0961 - output_1_loss: 52.7783 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.0077 - loss_prior: 0.6997 - loss_variational_1: 1.2549 - loss_variational_2: -0.6281 - loss_survival: 1.9836 - val_loss: 60.8549 - val_output_1_loss: 52.7929 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.7762 - val_loss_prior: 0.6995 - val_loss_variational_1: 1.2815 - val_loss_variational_2: -0.6640 - val_loss_survival: 1.9688
# Epoch 43/140
# 147/147 [==============================] - 3s 21ms/step - loss: 61.0040 - output_1_loss: 52.6878 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.9921 - loss_prior: 0.6999 - loss_variational_1: 1.2659 - loss_variational_2: -0.6253 - loss_survival: 1.9835 - val_loss: 60.5135 - val_output_1_loss: 52.5636 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.6933 - val_loss_prior: 0.7009 - val_loss_variational_1: 1.2373 - val_loss_variational_2: -0.6532 - val_loss_survival: 1.9716
# Epoch 44/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.9248 - output_1_loss: 52.5763 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.9771 - loss_prior: 0.7003 - loss_variational_1: 1.3169 - loss_variational_2: -0.6217 - loss_survival: 1.9760 - val_loss: 60.6053 - val_output_1_loss: 52.6003 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.6663 - val_loss_prior: 0.7007 - val_loss_variational_1: 1.3109 - val_loss_variational_2: -0.6516 - val_loss_survival: 1.9787
# Epoch 45/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.9887 - output_1_loss: 52.6490 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.9533 - loss_prior: 0.7007 - loss_variational_1: 1.3474 - loss_variational_2: -0.6144 - loss_survival: 1.9527 - val_loss: 60.1081 - val_output_1_loss: 52.1527 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.6684 - val_loss_prior: 0.7011 - val_loss_variational_1: 1.2850 - val_loss_variational_2: -0.6437 - val_loss_survival: 1.9446
# Epoch 46/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.9142 - output_1_loss: 52.6669 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.9255 - loss_prior: 0.7006 - loss_variational_1: 1.2797 - loss_variational_2: -0.6111 - loss_survival: 1.9526 - val_loss: 60.0915 - val_output_1_loss: 52.1855 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.6614 - val_loss_prior: 0.7009 - val_loss_variational_1: 1.2458 - val_loss_variational_2: -0.6409 - val_loss_survival: 1.9389
# Epoch 47/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.9970 - output_1_loss: 52.7090 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.9055 - loss_prior: 0.7003 - loss_variational_1: 1.3366 - loss_variational_2: -0.6101 - loss_survival: 1.9556 - val_loss: 60.3556 - val_output_1_loss: 52.3060 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.6295 - val_loss_prior: 0.7001 - val_loss_variational_1: 1.3903 - val_loss_variational_2: -0.6451 - val_loss_survival: 1.9750
# Epoch 48/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.8987 - output_1_loss: 52.6124 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.8794 - loss_prior: 0.7000 - loss_variational_1: 1.3583 - loss_variational_2: -0.6104 - loss_survival: 1.9590 - val_loss: 60.4639 - val_output_1_loss: 52.5514 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.6205 - val_loss_prior: 0.7008 - val_loss_variational_1: 1.3118 - val_loss_variational_2: -0.6310 - val_loss_survival: 1.9104
# Epoch 49/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.8898 - output_1_loss: 52.6534 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.8909 - loss_prior: 0.7001 - loss_variational_1: 1.3158 - loss_variational_2: -0.6020 - loss_survival: 1.9316 - val_loss: 60.2635 - val_output_1_loss: 52.3534 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.6031 - val_loss_prior: 0.7005 - val_loss_variational_1: 1.3134 - val_loss_variational_2: -0.6258 - val_loss_survival: 1.9190
# Epoch 50/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.8773 - output_1_loss: 52.7027 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.8896 - loss_prior: 0.6998 - loss_variational_1: 1.2525 - loss_variational_2: -0.5955 - loss_survival: 1.9282 - val_loss: 60.0549 - val_output_1_loss: 52.2395 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.5663 - val_loss_prior: 0.7001 - val_loss_variational_1: 1.2523 - val_loss_variational_2: -0.6231 - val_loss_survival: 1.9199
# Epoch 51/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.6721 - output_1_loss: 52.5558 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.8511 - loss_prior: 0.6992 - loss_variational_1: 1.2355 - loss_variational_2: -0.5978 - loss_survival: 1.9283 - val_loss: 60.2008 - val_output_1_loss: 52.2962 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.5800 - val_loss_prior: 0.6997 - val_loss_variational_1: 1.3491 - val_loss_variational_2: -0.6183 - val_loss_survival: 1.8940
# Epoch 52/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.7934 - output_1_loss: 52.6022 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.8559 - loss_prior: 0.6992 - loss_variational_1: 1.3087 - loss_variational_2: -0.5868 - loss_survival: 1.9143 - val_loss: 60.6434 - val_output_1_loss: 52.7820 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.5501 - val_loss_prior: 0.6992 - val_loss_variational_1: 1.3238 - val_loss_variational_2: -0.6172 - val_loss_survival: 1.9055
# Epoch 53/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.8239 - output_1_loss: 52.6694 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.8037 - loss_prior: 0.6986 - loss_variational_1: 1.3165 - loss_variational_2: -0.5873 - loss_survival: 1.9228 - val_loss: 60.6639 - val_output_1_loss: 52.8641 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.4997 - val_loss_prior: 0.6989 - val_loss_variational_1: 1.3070 - val_loss_variational_2: -0.6079 - val_loss_survival: 1.9022
# Epoch 54/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.7173 - output_1_loss: 52.6034 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.8037 - loss_prior: 0.6980 - loss_variational_1: 1.2758 - loss_variational_2: -0.5842 - loss_survival: 1.9206 - val_loss: 60.1042 - val_output_1_loss: 52.3314 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.5189 - val_loss_prior: 0.6982 - val_loss_variational_1: 1.2642 - val_loss_variational_2: -0.6090 - val_loss_survival: 1.9004
# Epoch 55/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.7402 - output_1_loss: 52.5955 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.8014 - loss_prior: 0.6978 - loss_variational_1: 1.3056 - loss_variational_2: -0.5760 - loss_survival: 1.9158 - val_loss: 59.9611 - val_output_1_loss: 52.2841 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.4690 - val_loss_prior: 0.6977 - val_loss_variational_1: 1.2023 - val_loss_variational_2: -0.6033 - val_loss_survival: 1.9112
# Epoch 56/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.7331 - output_1_loss: 52.6268 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.7915 - loss_prior: 0.6972 - loss_variational_1: 1.2736 - loss_variational_2: -0.5730 - loss_survival: 1.9172 - val_loss: 60.1433 - val_output_1_loss: 52.4094 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.4709 - val_loss_prior: 0.6970 - val_loss_variational_1: 1.2617 - val_loss_variational_2: -0.6044 - val_loss_survival: 1.9087
# Epoch 57/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.6898 - output_1_loss: 52.6088 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.7701 - loss_prior: 0.6966 - loss_variational_1: 1.2732 - loss_variational_2: -0.5723 - loss_survival: 1.9135 - val_loss: 60.0826 - val_output_1_loss: 52.3804 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.4337 - val_loss_prior: 0.6965 - val_loss_variational_1: 1.2651 - val_loss_variational_2: -0.5963 - val_loss_survival: 1.9031
# Epoch 58/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.7648 - output_1_loss: 52.6624 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.7523 - loss_prior: 0.6959 - loss_variational_1: 1.3044 - loss_variational_2: -0.5715 - loss_survival: 1.9212 - val_loss: 59.8943 - val_output_1_loss: 52.1421 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.4597 - val_loss_prior: 0.6959 - val_loss_variational_1: 1.3043 - val_loss_variational_2: -0.5937 - val_loss_survival: 1.8861
# Epoch 59/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.7184 - output_1_loss: 52.6123 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.7522 - loss_prior: 0.6954 - loss_variational_1: 1.3267 - loss_variational_2: -0.5637 - loss_survival: 1.8955 - val_loss: 60.1569 - val_output_1_loss: 52.4393 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.3908 - val_loss_prior: 0.6952 - val_loss_variational_1: 1.3125 - val_loss_variational_2: -0.5929 - val_loss_survival: 1.9120
# Epoch 60/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.7439 - output_1_loss: 52.6598 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.7513 - loss_prior: 0.6947 - loss_variational_1: 1.3028 - loss_variational_2: -0.5644 - loss_survival: 1.8998 - val_loss: 60.1031 - val_output_1_loss: 52.3042 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.4286 - val_loss_prior: 0.6946 - val_loss_variational_1: 1.3945 - val_loss_variational_2: -0.5820 - val_loss_survival: 1.8632
# Epoch 61/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.5681 - output_1_loss: 52.4752 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.7480 - loss_prior: 0.6941 - loss_variational_1: 1.3180 - loss_variational_2: -0.5581 - loss_survival: 1.8909 - val_loss: 59.9783 - val_output_1_loss: 52.2174 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.3617 - val_loss_prior: 0.6938 - val_loss_variational_1: 1.3716 - val_loss_variational_2: -0.5888 - val_loss_survival: 1.9225
# Epoch 62/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.6376 - output_1_loss: 52.6101 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.7184 - loss_prior: 0.6935 - loss_variational_1: 1.2717 - loss_variational_2: -0.5571 - loss_survival: 1.9011 - val_loss: 59.7587 - val_output_1_loss: 52.2266 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.3581 - val_loss_prior: 0.6931 - val_loss_variational_1: 1.1684 - val_loss_variational_2: -0.5773 - val_loss_survival: 1.8896
# Epoch 63/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.5944 - output_1_loss: 52.5664 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.7056 - loss_prior: 0.6928 - loss_variational_1: 1.2995 - loss_variational_2: -0.5571 - loss_survival: 1.8873 - val_loss: 60.1775 - val_output_1_loss: 52.5076 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.4127 - val_loss_prior: 0.6924 - val_loss_variational_1: 1.3086 - val_loss_variational_2: -0.5750 - val_loss_survival: 1.8312
# Epoch 64/140
# 147/147 [==============================] - 3s 20ms/step - loss: 60.5861 - output_1_loss: 52.5691 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.7096 - loss_prior: 0.6921 - loss_variational_1: 1.2840 - loss_variational_2: -0.5529 - loss_survival: 1.8840 - val_loss: 60.2994 - val_output_1_loss: 52.5786 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.3586 - val_loss_prior: 0.6916 - val_loss_variational_1: 1.3824 - val_loss_variational_2: -0.5669 - val_loss_survival: 1.8551
# Epoch 65/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.6128 - output_1_loss: 52.6020 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.7023 - loss_prior: 0.6914 - loss_variational_1: 1.2865 - loss_variational_2: -0.5469 - loss_survival: 1.8775 - val_loss: 59.8557 - val_output_1_loss: 52.2203 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.3613 - val_loss_prior: 0.6909 - val_loss_variational_1: 1.2934 - val_loss_variational_2: -0.5722 - val_loss_survival: 1.8620
# Epoch 66/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.5607 - output_1_loss: 52.5622 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.7140 - loss_prior: 0.6907 - loss_variational_1: 1.2550 - loss_variational_2: -0.5442 - loss_survival: 1.8831 - val_loss: 60.0640 - val_output_1_loss: 52.4279 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.3754 - val_loss_prior: 0.6902 - val_loss_variational_1: 1.3024 - val_loss_variational_2: -0.5695 - val_loss_survival: 1.8377
# Epoch 67/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.5611 - output_1_loss: 52.5383 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6877 - loss_prior: 0.6899 - loss_variational_1: 1.3146 - loss_variational_2: -0.5420 - loss_survival: 1.8725 - val_loss: 59.8659 - val_output_1_loss: 52.2593 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.3100 - val_loss_prior: 0.6894 - val_loss_variational_1: 1.3031 - val_loss_variational_2: -0.5689 - val_loss_survival: 1.8729
# Epoch 68/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.5103 - output_1_loss: 52.5457 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6920 - loss_prior: 0.6893 - loss_variational_1: 1.2332 - loss_variational_2: -0.5408 - loss_survival: 1.8908 - val_loss: 60.2029 - val_output_1_loss: 52.6750 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.3160 - val_loss_prior: 0.6886 - val_loss_variational_1: 1.2292 - val_loss_variational_2: -0.5639 - val_loss_survival: 1.8580
# Epoch 69/140
# 147/147 [==============================] - 3s 20ms/step - loss: 60.5819 - output_1_loss: 52.6129 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6524 - loss_prior: 0.6886 - loss_variational_1: 1.2860 - loss_variational_2: -0.5439 - loss_survival: 1.8860 - val_loss: 60.9944 - val_output_1_loss: 53.4770 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2546 - val_loss_prior: 0.6877 - val_loss_variational_1: 1.2547 - val_loss_variational_2: -0.5539 - val_loss_survival: 1.8744
# Epoch 70/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.5798 - output_1_loss: 52.5783 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6774 - loss_prior: 0.6879 - loss_variational_1: 1.2976 - loss_variational_2: -0.5399 - loss_survival: 1.8785 - val_loss: 59.8615 - val_output_1_loss: 52.2833 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2909 - val_loss_prior: 0.6869 - val_loss_variational_1: 1.3046 - val_loss_variational_2: -0.5538 - val_loss_survival: 1.8495
# Epoch 71/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.5578 - output_1_loss: 52.5787 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6803 - loss_prior: 0.6872 - loss_variational_1: 1.2738 - loss_variational_2: -0.5376 - loss_survival: 1.8754 - val_loss: 59.8577 - val_output_1_loss: 52.3445 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2781 - val_loss_prior: 0.6865 - val_loss_variational_1: 1.2423 - val_loss_variational_2: -0.5654 - val_loss_survival: 1.8717
# Epoch 72/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.6969 - output_1_loss: 52.6888 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6705 - loss_prior: 0.6865 - loss_variational_1: 1.3252 - loss_variational_2: -0.5365 - loss_survival: 1.8624 - val_loss: 60.1875 - val_output_1_loss: 52.6075 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2869 - val_loss_prior: 0.6852 - val_loss_variational_1: 1.3334 - val_loss_variational_2: -0.5455 - val_loss_survival: 1.8200
# Epoch 73/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.4967 - output_1_loss: 52.5511 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6617 - loss_prior: 0.6856 - loss_variational_1: 1.2775 - loss_variational_2: -0.5329 - loss_survival: 1.8536 - val_loss: 59.9652 - val_output_1_loss: 52.4078 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2802 - val_loss_prior: 0.6849 - val_loss_variational_1: 1.2978 - val_loss_variational_2: -0.5585 - val_loss_survival: 1.8530
# Epoch 74/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.4476 - output_1_loss: 52.5384 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6321 - loss_prior: 0.6850 - loss_variational_1: 1.2736 - loss_variational_2: -0.5347 - loss_survival: 1.8532 - val_loss: 59.7669 - val_output_1_loss: 52.2666 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2715 - val_loss_prior: 0.6839 - val_loss_variational_1: 1.2586 - val_loss_variational_2: -0.5530 - val_loss_survival: 1.8392
# Epoch 75/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.4062 - output_1_loss: 52.5215 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6567 - loss_prior: 0.6843 - loss_variational_1: 1.2131 - loss_variational_2: -0.5291 - loss_survival: 1.8599 - val_loss: 59.9031 - val_output_1_loss: 52.4752 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2240 - val_loss_prior: 0.6831 - val_loss_variational_1: 1.2189 - val_loss_variational_2: -0.5493 - val_loss_survival: 1.8513
# Epoch 76/140
# 147/147 [==============================] - 3s 20ms/step - loss: 60.5242 - output_1_loss: 52.5909 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6418 - loss_prior: 0.6836 - loss_variational_1: 1.2782 - loss_variational_2: -0.5285 - loss_survival: 1.8582 - val_loss: 59.6843 - val_output_1_loss: 52.2602 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2450 - val_loss_prior: 0.6823 - val_loss_variational_1: 1.2041 - val_loss_variational_2: -0.5477 - val_loss_survival: 1.8405
# Epoch 77/140
# 147/147 [==============================] - 3s 20ms/step - loss: 60.4329 - output_1_loss: 52.5519 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6390 - loss_prior: 0.6829 - loss_variational_1: 1.2256 - loss_variational_2: -0.5276 - loss_survival: 1.8612 - val_loss: 59.9009 - val_output_1_loss: 52.4663 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2261 - val_loss_prior: 0.6814 - val_loss_variational_1: 1.2401 - val_loss_variational_2: -0.5438 - val_loss_survival: 1.8308
# Epoch 78/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.3943 - output_1_loss: 52.4840 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6181 - loss_prior: 0.6820 - loss_variational_1: 1.2693 - loss_variational_2: -0.5267 - loss_survival: 1.8675 - val_loss: 59.8492 - val_output_1_loss: 52.3509 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2236 - val_loss_prior: 0.6807 - val_loss_variational_1: 1.3073 - val_loss_variational_2: -0.5453 - val_loss_survival: 1.8320
# Epoch 79/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.4456 - output_1_loss: 52.5087 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6339 - loss_prior: 0.6811 - loss_variational_1: 1.2866 - loss_variational_2: -0.5214 - loss_survival: 1.8566 - val_loss: 59.6178 - val_output_1_loss: 52.1554 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2232 - val_loss_prior: 0.6800 - val_loss_variational_1: 1.2725 - val_loss_variational_2: -0.5472 - val_loss_survival: 1.8339
# Epoch 80/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.4856 - output_1_loss: 52.5566 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6197 - loss_prior: 0.6804 - loss_variational_1: 1.2835 - loss_variational_2: -0.5205 - loss_survival: 1.8659 - val_loss: 59.7849 - val_output_1_loss: 52.2481 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2126 - val_loss_prior: 0.6795 - val_loss_variational_1: 1.3377 - val_loss_variational_2: -0.5499 - val_loss_survival: 1.8570
# Epoch 81/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.4612 - output_1_loss: 52.5586 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6109 - loss_prior: 0.6801 - loss_variational_1: 1.2846 - loss_variational_2: -0.5269 - loss_survival: 1.8540 - val_loss: 59.8295 - val_output_1_loss: 52.3540 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2198 - val_loss_prior: 0.6782 - val_loss_variational_1: 1.3090 - val_loss_variational_2: -0.5394 - val_loss_survival: 1.8079
# Epoch 82/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.3868 - output_1_loss: 52.5222 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6282 - loss_prior: 0.6791 - loss_variational_1: 1.2375 - loss_variational_2: -0.5211 - loss_survival: 1.8408 - val_loss: 59.9280 - val_output_1_loss: 52.4564 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2146 - val_loss_prior: 0.6777 - val_loss_variational_1: 1.3079 - val_loss_variational_2: -0.5444 - val_loss_survival: 1.8158
# Epoch 83/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.5005 - output_1_loss: 52.5796 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6152 - loss_prior: 0.6781 - loss_variational_1: 1.2882 - loss_variational_2: -0.5173 - loss_survival: 1.8567 - val_loss: 59.6854 - val_output_1_loss: 52.1699 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.1821 - val_loss_prior: 0.6774 - val_loss_variational_1: 1.3376 - val_loss_variational_2: -0.5516 - val_loss_survival: 1.8700
# Epoch 84/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.4289 - output_1_loss: 52.5580 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.5920 - loss_prior: 0.6779 - loss_variational_1: 1.2719 - loss_variational_2: -0.5223 - loss_survival: 1.8513 - val_loss: 59.5572 - val_output_1_loss: 52.1711 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2155 - val_loss_prior: 0.6760 - val_loss_variational_1: 1.2277 - val_loss_variational_2: -0.5388 - val_loss_survival: 1.8057
# Epoch 85/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.4199 - output_1_loss: 52.5562 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.5880 - loss_prior: 0.6769 - loss_variational_1: 1.2772 - loss_variational_2: -0.5204 - loss_survival: 1.8421 - val_loss: 59.7374 - val_output_1_loss: 52.2431 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2292 - val_loss_prior: 0.6752 - val_loss_variational_1: 1.3383 - val_loss_variational_2: -0.5379 - val_loss_survival: 1.7896
# Epoch 86/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.3409 - output_1_loss: 52.4936 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6068 - loss_prior: 0.6764 - loss_variational_1: 1.2628 - loss_variational_2: -0.5207 - loss_survival: 1.8220 - val_loss: 59.6437 - val_output_1_loss: 52.1750 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2132 - val_loss_prior: 0.6744 - val_loss_variational_1: 1.3297 - val_loss_variational_2: -0.5375 - val_loss_survival: 1.7889
# Epoch 87/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.2991 - output_1_loss: 52.4573 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6118 - loss_prior: 0.6755 - loss_variational_1: 1.2448 - loss_variational_2: -0.5158 - loss_survival: 1.8256 - val_loss: 59.4481 - val_output_1_loss: 52.1345 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.2040 - val_loss_prior: 0.6733 - val_loss_variational_1: 1.1797 - val_loss_variational_2: -0.5317 - val_loss_survival: 1.7884
# Epoch 88/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.3158 - output_1_loss: 52.4605 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.6133 - loss_prior: 0.6747 - loss_variational_1: 1.2471 - loss_variational_2: -0.5142 - loss_survival: 1.8344 - val_loss: 59.9410 - val_output_1_loss: 52.6040 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.1473 - val_loss_prior: 0.6723 - val_loss_variational_1: 1.2377 - val_loss_variational_2: -0.5278 - val_loss_survival: 1.8073
# Epoch 89/140
# ...
# Epoch 112/140
# 147/147 [==============================] - 3s 20ms/step - loss: 60.2826 - output_1_loss: 52.5266 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.5327 - loss_prior: 0.6575 - loss_variational_1: 1.2928 - loss_variational_2: -0.5028 - loss_survival: 1.7759 - val_loss: 60.1103 - val_output_1_loss: 52.8434 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0553 - val_loss_prior: 0.6530 - val_loss_variational_1: 1.3157 - val_loss_variational_2: -0.5115 - val_loss_survival: 1.7544
# Epoch 113/140
# 147/147 [==============================] - 3s 20ms/step - loss: 60.1783 - output_1_loss: 52.4823 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.5004 - loss_prior: 0.6566 - loss_variational_1: 1.2725 - loss_variational_2: -0.5025 - loss_survival: 1.7690 - val_loss: 59.5940 - val_output_1_loss: 52.4360 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0524 - val_loss_prior: 0.6531 - val_loss_variational_1: 1.2093 - val_loss_variational_2: -0.5185 - val_loss_survival: 1.7616
# Epoch 114/140
# 147/147 [==============================] - 3s 20ms/step - loss: 60.1745 - output_1_loss: 52.4794 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.5190 - loss_prior: 0.6561 - loss_variational_1: 1.2571 - loss_variational_2: -0.5029 - loss_survival: 1.7657 - val_loss: 59.5254 - val_output_1_loss: 52.4112 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0841 - val_loss_prior: 0.6522 - val_loss_variational_1: 1.1604 - val_loss_variational_2: -0.5166 - val_loss_survival: 1.7340
# Epoch 115/140
# 147/147 [==============================] - 3s 20ms/step - loss: 60.2419 - output_1_loss: 52.5371 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.5170 - loss_prior: 0.6549 - loss_variational_1: 1.2682 - loss_variational_2: -0.5001 - loss_survival: 1.7648 - val_loss: 59.5914 - val_output_1_loss: 52.3969 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0632 - val_loss_prior: 0.6518 - val_loss_variational_1: 1.2506 - val_loss_variational_2: -0.5190 - val_loss_survival: 1.7480
# Epoch 116/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.2131 - output_1_loss: 52.4857 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.5048 - loss_prior: 0.6545 - loss_variational_1: 1.2918 - loss_variational_2: -0.5010 - loss_survival: 1.7774 - val_loss: 59.8179 - val_output_1_loss: 52.5461 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0589 - val_loss_prior: 0.6511 - val_loss_variational_1: 1.3301 - val_loss_variational_2: -0.5193 - val_loss_survival: 1.7510
# Epoch 117/140
# 147/147 [==============================] - 3s 20ms/step - loss: 60.0923 - output_1_loss: 52.4227 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.5119 - loss_prior: 0.6540 - loss_variational_1: 1.2390 - loss_variational_2: -0.5008 - loss_survival: 1.7655 - val_loss: 59.7169 - val_output_1_loss: 52.5130 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0570 - val_loss_prior: 0.6502 - val_loss_variational_1: 1.2807 - val_loss_variational_2: -0.5177 - val_loss_survival: 1.7337
# Epoch 118/140
# 147/147 [==============================] - 3s 20ms/step - loss: 60.2253 - output_1_loss: 52.5453 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.4914 - loss_prior: 0.6534 - loss_variational_1: 1.2784 - loss_variational_2: -0.5019 - loss_survival: 1.7587 - val_loss: 59.4950 - val_output_1_loss: 52.3347 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0617 - val_loss_prior: 0.6488 - val_loss_variational_1: 1.2292 - val_loss_variational_2: -0.5127 - val_loss_survival: 1.7333
# Epoch 119/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.1681 - output_1_loss: 52.4206 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.5208 - loss_prior: 0.6524 - loss_variational_1: 1.3242 - loss_variational_2: -0.4982 - loss_survival: 1.7484 - val_loss: 59.6780 - val_output_1_loss: 52.3896 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0608 - val_loss_prior: 0.6490 - val_loss_variational_1: 1.3593 - val_loss_variational_2: -0.5191 - val_loss_survival: 1.7385
# Epoch 120/140
# 147/147 [==============================] - 3s 20ms/step - loss: 60.0810 - output_1_loss: 52.3905 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.4902 - loss_prior: 0.6515 - loss_variational_1: 1.2953 - loss_variational_2: -0.4983 - loss_survival: 1.7518 - val_loss: 59.4962 - val_output_1_loss: 52.2923 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0200 - val_loss_prior: 0.6482 - val_loss_variational_1: 1.2899 - val_loss_variational_2: -0.5184 - val_loss_survival: 1.7642
# Epoch 121/140
# 147/147 [==============================] - 3s 20ms/step - loss: 60.0324 - output_1_loss: 52.3774 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.4880 - loss_prior: 0.6507 - loss_variational_1: 1.2503 - loss_variational_2: -0.4966 - loss_survival: 1.7626 - val_loss: 59.1526 - val_output_1_loss: 51.9478 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0366 - val_loss_prior: 0.6485 - val_loss_variational_1: 1.2878 - val_loss_variational_2: -0.5256 - val_loss_survival: 1.7575
# Epoch 122/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.0749 - output_1_loss: 52.4432 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.4849 - loss_prior: 0.6508 - loss_variational_1: 1.2426 - loss_variational_2: -0.5013 - loss_survival: 1.7548 - val_loss: 60.1283 - val_output_1_loss: 52.9865 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0739 - val_loss_prior: 0.6465 - val_loss_variational_1: 1.2301 - val_loss_variational_2: -0.5165 - val_loss_survival: 1.7078
# Epoch 123/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.0670 - output_1_loss: 52.4482 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.4898 - loss_prior: 0.6494 - loss_variational_1: 1.2305 - loss_variational_2: -0.4973 - loss_survival: 1.7463 - val_loss: 59.3304 - val_output_1_loss: 52.2855 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0627 - val_loss_prior: 0.6459 - val_loss_variational_1: 1.1421 - val_loss_variational_2: -0.5169 - val_loss_survival: 1.7111
# Epoch 124/140
# 147/147 [==============================] - 3s 20ms/step - loss: 59.9777 - output_1_loss: 52.3678 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.4926 - loss_prior: 0.6492 - loss_variational_1: 1.2222 - loss_variational_2: -0.4997 - loss_survival: 1.7456 - val_loss: 59.4370 - val_output_1_loss: 52.3210 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0561 - val_loss_prior: 0.6446 - val_loss_variational_1: 1.2179 - val_loss_variational_2: -0.5130 - val_loss_survival: 1.7104
# Epoch 125/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.0686 - output_1_loss: 52.4339 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.4942 - loss_prior: 0.6477 - loss_variational_1: 1.2440 - loss_variational_2: -0.4955 - loss_survival: 1.7443 - val_loss: 59.5774 - val_output_1_loss: 52.4562 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0138 - val_loss_prior: 0.6441 - val_loss_variational_1: 1.2401 - val_loss_variational_2: -0.5145 - val_loss_survival: 1.7378
# Epoch 126/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.0544 - output_1_loss: 52.4289 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.4760 - loss_prior: 0.6479 - loss_variational_1: 1.2520 - loss_variational_2: -0.4985 - loss_survival: 1.7482 - val_loss: 59.3703 - val_output_1_loss: 52.2014 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0241 - val_loss_prior: 0.6435 - val_loss_variational_1: 1.2899 - val_loss_variational_2: -0.5150 - val_loss_survival: 1.7265
# Epoch 127/140
# 147/147 [==============================] - 3s 20ms/step - loss: 60.0190 - output_1_loss: 52.3671 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.4915 - loss_prior: 0.6464 - loss_variational_1: 1.2691 - loss_variational_2: -0.4947 - loss_survival: 1.7396 - val_loss: 59.6886 - val_output_1_loss: 52.5412 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0290 - val_loss_prior: 0.6431 - val_loss_variational_1: 1.2621 - val_loss_variational_2: -0.5173 - val_loss_survival: 1.7304
# Epoch 128/140
# 147/147 [==============================] - 3s 20ms/step - loss: 60.0648 - output_1_loss: 52.4236 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.4790 - loss_prior: 0.6463 - loss_variational_1: 1.2641 - loss_variational_2: -0.4962 - loss_survival: 1.7480 - val_loss: 59.5995 - val_output_1_loss: 52.4481 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 3.9955 - val_loss_prior: 0.6411 - val_loss_variational_1: 1.2948 - val_loss_variational_2: -0.5087 - val_loss_survival: 1.7287
# Epoch 129/140
# 147/147 [==============================] - 3s 20ms/step - loss: 60.1165 - output_1_loss: 52.4887 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.4880 - loss_prior: 0.6463 - loss_variational_1: 1.2558 - loss_variational_2: -0.4989 - loss_survival: 1.7366 - val_loss: 59.1283 - val_output_1_loss: 52.0306 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0365 - val_loss_prior: 0.6411 - val_loss_variational_1: 1.2316 - val_loss_variational_2: -0.5126 - val_loss_survival: 1.7012
# Epoch 130/140
# 147/147 [==============================] - 3s 20ms/step - loss: 60.0051 - output_1_loss: 52.4076 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.4820 - loss_prior: 0.6440 - loss_variational_1: 1.2368 - loss_variational_2: -0.4921 - loss_survival: 1.7268 - val_loss: 59.2796 - val_output_1_loss: 52.2978 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0083 - val_loss_prior: 0.6403 - val_loss_variational_1: 1.1289 - val_loss_variational_2: -0.5122 - val_loss_survival: 1.7165
# Epoch 131/140
# 147/147 [==============================] - 3s 21ms/step - loss: 60.1432 - output_1_loss: 52.4941 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.5075 - loss_prior: 0.6439 - loss_variational_1: 1.2385 - loss_variational_2: -0.4917 - loss_survival: 1.7509 - val_loss: 59.7697 - val_output_1_loss: 52.5106 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 3.9969 - val_loss_prior: 0.6401 - val_loss_variational_1: 1.4044 - val_loss_variational_2: -0.5158 - val_loss_survival: 1.7334
# Epoch 132/140
# 147/147 [==============================] - 3s 20ms/step - loss: 59.9894 - output_1_loss: 52.3770 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.4617 - loss_prior: 0.6435 - loss_variational_1: 1.2870 - loss_variational_2: -0.4979 - loss_survival: 1.7180 - val_loss: 59.5119 - val_output_1_loss: 52.4848 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0021 - val_loss_prior: 0.6386 - val_loss_variational_1: 1.1817 - val_loss_variational_2: -0.5100 - val_loss_survival: 1.7148
# Epoch 133/140
# 147/147 [==============================] - 3s 20ms/step - loss: 59.9540 - output_1_loss: 52.3200 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.5133 - loss_prior: 0.6430 - loss_variational_1: 1.2342 - loss_variational_2: -0.4924 - loss_survival: 1.7358 - val_loss: 59.3669 - val_output_1_loss: 52.2293 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0081 - val_loss_prior: 0.6394 - val_loss_variational_1: 1.2777 - val_loss_variational_2: -0.5197 - val_loss_survival: 1.7319
# Epoch 134/140
# 147/147 [==============================] - 3s 21ms/step - loss: 59.8960 - output_1_loss: 52.2917 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.5092 - loss_prior: 0.6430 - loss_variational_1: 1.2170 - loss_variational_2: -0.4957 - loss_survival: 1.7308 - val_loss: 59.7197 - val_output_1_loss: 52.5529 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0095 - val_loss_prior: 0.6376 - val_loss_variational_1: 1.3288 - val_loss_variational_2: -0.5124 - val_loss_survival: 1.7035
# Epoch 135/140
# 147/147 [==============================] - 3s 20ms/step - loss: 59.8690 - output_1_loss: 52.2346 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.5307 - loss_prior: 0.6414 - loss_variational_1: 1.2138 - loss_variational_2: -0.4893 - loss_survival: 1.7377 - val_loss: 59.4754 - val_output_1_loss: 52.4894 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 3.9766 - val_loss_prior: 0.6373 - val_loss_variational_1: 1.1468 - val_loss_variational_2: -0.5147 - val_loss_survival: 1.7401
# Epoch 136/140
# 147/147 [==============================] - 3s 20ms/step - loss: 59.5548 - output_1_loss: 51.8856 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.5961 - loss_prior: 0.6414 - loss_variational_1: 1.1923 - loss_variational_2: -0.4908 - loss_survival: 1.7301 - val_loss: 60.1410 - val_output_1_loss: 53.0758 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 3.9680 - val_loss_prior: 0.6363 - val_loss_variational_1: 1.2375 - val_loss_variational_2: -0.5129 - val_loss_survival: 1.7363
# Epoch 137/140
# 147/147 [==============================] - 3s 21ms/step - loss: 58.3560 - output_1_loss: 50.4067 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 4.8869 - loss_prior: 0.6430 - loss_variational_1: 1.1648 - loss_variational_2: -0.4874 - loss_survival: 1.7419 - val_loss: 60.0017 - val_output_1_loss: 52.6083 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 3.9799 - val_loss_prior: 0.6384 - val_loss_variational_1: 1.5409 - val_loss_variational_2: -0.5283 - val_loss_survival: 1.7626
# Epoch 138/140
# 147/147 [==============================] - 3s 20ms/step - loss: 56.8081 - output_1_loss: 48.5739 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.0362 - loss_prior: 0.6419 - loss_variational_1: 1.3061 - loss_variational_2: -0.4879 - loss_survival: 1.7379 - val_loss: 60.8652 - val_output_1_loss: 53.3516 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 3.9958 - val_loss_prior: 0.6355 - val_loss_variational_1: 1.6875 - val_loss_variational_2: -0.5155 - val_loss_survival: 1.7104
# Epoch 139/140
# 147/147 [==============================] - 3s 20ms/step - loss: 55.4335 - output_1_loss: 47.1457 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.0013 - loss_prior: 0.6426 - loss_variational_1: 1.4141 - loss_variational_2: -0.4954 - loss_survival: 1.7252 - val_loss: 60.4506 - val_output_1_loss: 53.1485 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0052 - val_loss_prior: 0.6368 - val_loss_variational_1: 1.4635 - val_loss_variational_2: -0.5263 - val_loss_survival: 1.7230
# Epoch 140/140
# 147/147 [==============================] - 3s 20ms/step - loss: 54.6819 - output_1_loss: 46.1551 - output_2_cindex_metric: 0.0000e+00 - loss_clustering: 5.0970 - loss_prior: 0.6421 - loss_variational_1: 1.5476 - loss_variational_2: -0.4972 - loss_survival: 1.7373 - val_loss: 61.3475 - val_output_1_loss: 53.9832 - val_output_2_cindex_metric: 0.0000e+00 - val_loss_clustering: 4.0195 - val_loss_prior: 0.6370 - val_loss_variational_1: 1.5132 - val_loss_variational_2: -0.5306 - val_loss_survival: 1.7253
# Model: "GMM_Survival"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (Encoder)            multiple                  7103004
# _________________________________________________________________
# dec (Decoder)                multiple                  7110684
# =================================================================
# Total params: 14,213,701
# Trainable params: 14,213,700
# Non-trainable params: 1
# _________________________________________________________________

# %%
tf.keras.backend.set_value(model.use_t, np.array([0.0]))

model.sample_surv = False

rec, z_sample, p_z_c, p_c_z, risk_scores, lambdas = model.predict((X_train, Y_train), batch_size=16)

risk_scores = np.squeeze(risk_scores)

# Hard cluster assignments
c_hat = np.argmax(p_c_z, axis=-1)

# %%
CB_COLOR_CYCLE = ['#377eb8', '#ff7f00', '#4daf4a', '#f781bf', '#a65628', '#984ea3', '#999999', '#e41a1c', '#dede00']

# %% [markdown]
# ### kaplan_meier

# %%
plot_bigroup_kaplan_meier(t=Y_train[:,0], d=Y_train[:,1],c_=c_hat ,legend=True, legend_outside=True)

# %% [markdown]
# ### CoxPH

# %%
with open('./processedData/TotalData1.pkl', 'rb') as f:
     Totaldata = pickle.load(f)

# %%
data = Totaldata.iloc[:, 2:]
cph = CoxPHFitter()
cph.fit(data, duration_col='time', event_col='event')

kmeans = KMeans(n_clusters=2)
kmeans.fit(cph.predict_survival_function(data).T)

np.unique(kmeans.labels_, return_counts=True)

cluster_labels = kmeans.labels_
kmf = KaplanMeierFitter()

plt.figure()

for cluster in np.unique(cluster_labels):
    idx = cluster_labels == cluster
    kmf.fit(data.loc[idx, 'time'], event_observed=data.loc[idx, 'event'], label=f'Cluster {cluster}')
    kmf.plot(ci_show=False)

plt.title('Kaplan-Meier Survival Curves by K-means Cluster')
plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.legend()
plt.show()
# Out:
# C:\Users\user\anaconda3\envs\ai\lib\site-packages\lifelines\utils\__init__.py:1188: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# C:\Users\user\anaconda3\envs\ai\lib\site-packages\lifelines\utils\__init__.py:1188: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# C:\Users\user\anaconda3\envs\ai\lib\site-packages\lifelines\utils\__init__.py:1188: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)

# %%
Y_train = np.append(Y_train, np.reshape(c_hat, (Y_train.shape[0], 1)), axis=1)
cols = ['time','event','cluster']
coxdata = pd.DataFrame(Y_train,columns=cols)
dataset = coxdata

# %% [markdown]
# ### K-MEANS

# %%
X_train.shape
# Out:
# (2353, 11684)

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(X_train)

# Get the cluster labels for each sample
labels = kmeans.labels_
survival_curves = []

for label in np.unique(labels):
    cluster_indices = np.where(labels == label)

    tte = Y_train[:,0]
    event = Y_train[:,1]
    # Fit the Kaplan-Meier estimator to the data in the current cluster
    kmf = KaplanMeierFitter()
    kmf.fit(tte[cluster_indices], event[cluster_indices], label=f"Cluster {label}")
    

    # Add the fitted Kaplan-Meier curve to the list of survival curves
    survival_curves.append(kmf)

# Plot the survival curves for each cluster
for kmf in survival_curves:
    kmf.plot()
    
plt.title("Survival Curve by cluster")
plt.xlabel("Time")
plt.ylabel("Survival Probability")

plt.show()
